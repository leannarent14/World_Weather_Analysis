# %%
import numpy as np
from citipy import citipy
import gmaps
import requests
import pandas as pd
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
# Generate 2,000 random latitutes and longitues, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0, size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# %%
# Get the nearest city using the citipy module
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0], coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['hermanus', 'leningradskiy', 'lucapa', 'kapaa', 'mar del plata', 'umm lajj', 'rikitea', 'maseru', 'ushuaia', 'nizhniy kuranakh'] Generate 738

# %%
# Perform an API call with the OpenWeatherMap.

record_count = 1
set_count = 1

city_data = list()
basic_url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0    

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description,
                        'Rain inches (last 3 hrs)':city_rain,'Snow inches (last 3 hrs)':city_snow})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | leningradskiy
# Processing Record 3 of Set 1 | lucapa
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | umm lajj
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | maseru
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | nizhniy kuranakh
# Processing Record 11 of Set 1 | acari
# Processing Record 12 of Set 1 | bambous virieux
# Processing Record 13 of Set 1 | tabas
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | port lincoln
# Processing Record 16 of Set 1 | ahipara
# Processing Record 17 of Set 1 | cooma
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | esperance
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | alofi
# Processing Record 22 of Set 1 | vanimo
# Processing Record 23 of Set 1 | longyearbyen
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | vzmorye
# Processing Record 26 of Set 1 | castro
# Processing Record 27 of Set 1 | high level
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | srednekolymsk
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | palmas bellas
# Processing Record 32 of Set 1 | fort nelson
# Processing Record 33 of Set 1 | faanui
# Processing Record 34 of Set 1 | la libertad
# Processing Record 35 of Set 1 | kamp-lintfort
# Processing Record 36 of Set 1 | yerbogachen
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | nueva loja
# Processing Record 39 of Set 1 | chuy
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | rio gallegos
# Processing Record 42 of Set 1 | souillac
# Processing Record 43 of Set 1 | norman wells
# Processing Record 44 of Set 1 | kutum
# Processing Record 45 of Set 1 | sitka
# Processing Record 46 of Set 1 | doha
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | hermiston
# Processing Record 49 of Set 1 | cam pha
# City not found. Skipping...
# Processing Record 50 of Set 1 | sinop
# Processing Record 1 of Set 2 | east london
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | ancud
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | pagudpud
# Processing Record 7 of Set 2 | lagoa
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | clyde river
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | mount gambier
# Processing Record 13 of Set 2 | pevek
# Processing Record 14 of Set 2 | diamantino
# Processing Record 15 of Set 2 | gizo
# Processing Record 16 of Set 2 | pemangkat
# Processing Record 17 of Set 2 | isla mujeres
# Processing Record 18 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 2 | general roca
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | kavieng
# Processing Record 22 of Set 2 | chabahar
# Processing Record 23 of Set 2 | saint george
# Processing Record 24 of Set 2 | keti bandar
# Processing Record 25 of Set 2 | yuzawa
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | rancho palos verdes
# Processing Record 29 of Set 2 | saint-pierre
# Processing Record 30 of Set 2 | san pedro
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | guamal
# Processing Record 33 of Set 2 | umm kaddadah
# Processing Record 34 of Set 2 | omboue
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | narrabri
# Processing Record 37 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 2 | hovd
# Processing Record 39 of Set 2 | katsuura
# Processing Record 40 of Set 2 | bose
# Processing Record 41 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 2 | saldanha
# Processing Record 43 of Set 2 | xingyi
# Processing Record 44 of Set 2 | chokurdakh
# Processing Record 45 of Set 2 | sungai padi
# Processing Record 46 of Set 2 | the valley
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | basco
# Processing Record 50 of Set 2 | dubbo
# Processing Record 1 of Set 3 | kharan
# Processing Record 2 of Set 3 | whitehorse
# Processing Record 3 of Set 3 | khatanga
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 3 | nouadhibou
# Processing Record 7 of Set 3 | bethel
# Processing Record 8 of Set 3 | mogadishu
# Processing Record 9 of Set 3 | sompeta
# Processing Record 10 of Set 3 | kizu
# City not found. Skipping...
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | cherskiy
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | talbahat
# Processing Record 17 of Set 3 | nishihara
# Processing Record 18 of Set 3 | genhe
# Processing Record 19 of Set 3 | houma
# Processing Record 20 of Set 3 | magadan
# Processing Record 21 of Set 3 | kirakira
# Processing Record 22 of Set 3 | hami
# Processing Record 23 of Set 3 | nuuk
# Processing Record 24 of Set 3 | matagami
# Processing Record 25 of Set 3 | georgetown
# Processing Record 26 of Set 3 | carnarvon
# Processing Record 27 of Set 3 | cabo san lucas
# Processing Record 28 of Set 3 | talnakh
# Processing Record 29 of Set 3 | srinivaspur
# Processing Record 30 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 3 | kishapu
# Processing Record 32 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 3 | along
# Processing Record 35 of Set 3 | saint-augustin
# Processing Record 36 of Set 3 | anar darreh
# City not found. Skipping...
# Processing Record 37 of Set 3 | husainabad
# Processing Record 38 of Set 3 | karratha
# Processing Record 39 of Set 3 | sibolga
# Processing Record 40 of Set 3 | shemordan
# Processing Record 41 of Set 3 | hamilton
# Processing Record 42 of Set 3 | tucuma
# Processing Record 43 of Set 3 | gat
# Processing Record 44 of Set 3 | rincon
# Processing Record 45 of Set 3 | saint-joseph
# Processing Record 46 of Set 3 | alyangula
# Processing Record 47 of Set 3 | acarau
# Processing Record 48 of Set 3 | kaitangata
# Processing Record 49 of Set 3 | mayo
# Processing Record 50 of Set 3 | narok
# Processing Record 1 of Set 4 | kuala lipis
# Processing Record 2 of Set 4 | bandar-e lengeh
# Processing Record 3 of Set 4 | presidencia roque saenz pena
# Processing Record 4 of Set 4 | thompson
# Processing Record 5 of Set 4 | sambava
# Processing Record 6 of Set 4 | atuona
# Processing Record 7 of Set 4 | cap-aux-meules
# Processing Record 8 of Set 4 | bayir
# Processing Record 9 of Set 4 | fort-shevchenko
# Processing Record 10 of Set 4 | la baule-escoublac
# Processing Record 11 of Set 4 | victoria
# Processing Record 12 of Set 4 | pangnirtung
# Processing Record 13 of Set 4 | achutupo
# Processing Record 14 of Set 4 | paucartambo
# City not found. Skipping...
# Processing Record 15 of Set 4 | ixtapa
# Processing Record 16 of Set 4 | sadiqabad
# Processing Record 17 of Set 4 | paamiut
# Processing Record 18 of Set 4 | te anau
# Processing Record 19 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 4 | waddan
# Processing Record 21 of Set 4 | narsaq
# Processing Record 22 of Set 4 | taveta
# Processing Record 23 of Set 4 | namatanai
# Processing Record 24 of Set 4 | youhao
# Processing Record 25 of Set 4 | ranong
# Processing Record 26 of Set 4 | berlevag
# Processing Record 27 of Set 4 | saint-philippe
# Processing Record 28 of Set 4 | lebu
# Processing Record 29 of Set 4 | dikson
# Processing Record 30 of Set 4 | butaritari
# Processing Record 31 of Set 4 | doksy
# Processing Record 32 of Set 4 | sicuani
# Processing Record 33 of Set 4 | arraial do cabo
# Processing Record 34 of Set 4 | bonfim
# Processing Record 35 of Set 4 | mackenzie
# Processing Record 36 of Set 4 | aden
# Processing Record 37 of Set 4 | ayan
# Processing Record 38 of Set 4 | belmonte
# Processing Record 39 of Set 4 | aklavik
# Processing Record 40 of Set 4 | ponta delgada
# Processing Record 41 of Set 4 | lenger
# Processing Record 42 of Set 4 | sijunjung
# Processing Record 43 of Set 4 | terney
# Processing Record 44 of Set 4 | henties bay
# Processing Record 45 of Set 4 | lata
# Processing Record 46 of Set 4 | morden
# Processing Record 47 of Set 4 | xiamen
# Processing Record 48 of Set 4 | bonthe
# Processing Record 49 of Set 4 | flinders
# Processing Record 50 of Set 4 | vega de alatorre
# Processing Record 1 of Set 5 | chase
# Processing Record 2 of Set 5 | venice
# Processing Record 3 of Set 5 | kyrksaeterora
# Processing Record 4 of Set 5 | contamana
# Processing Record 5 of Set 5 | provideniya
# Processing Record 6 of Set 5 | bengkulu
# Processing Record 7 of Set 5 | batagay
# Processing Record 8 of Set 5 | erenhot
# Processing Record 9 of Set 5 | palimbang
# Processing Record 10 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 5 | kaeo
# Processing Record 12 of Set 5 | codrington
# Processing Record 13 of Set 5 | nelson bay
# Processing Record 14 of Set 5 | temir
# Processing Record 15 of Set 5 | nantucket
# Processing Record 16 of Set 5 | shingu
# Processing Record 17 of Set 5 | isangel
# Processing Record 18 of Set 5 | constitucion
# Processing Record 19 of Set 5 | kyra
# Processing Record 20 of Set 5 | guerrero negro
# Processing Record 21 of Set 5 | hasaki
# Processing Record 22 of Set 5 | port elizabeth
# Processing Record 23 of Set 5 | yambio
# Processing Record 24 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 5 | olafsvik
# Processing Record 26 of Set 5 | noyabrsk
# Processing Record 27 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 28 of Set 5 | praia da vitoria
# Processing Record 29 of Set 5 | kirkwall
# Processing Record 30 of Set 5 | nikolsk
# Processing Record 31 of Set 5 | mahebourg
# Processing Record 32 of Set 5 | tacuarembo
# Processing Record 33 of Set 5 | brae
# Processing Record 34 of Set 5 | lompoc
# Processing Record 35 of Set 5 | biak
# Processing Record 36 of Set 5 | santa helena
# Processing Record 37 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 38 of Set 5 | urengoy
# Processing Record 39 of Set 5 | rocha
# Processing Record 40 of Set 5 | atar
# Processing Record 41 of Set 5 | sao filipe
# Processing Record 42 of Set 5 | port augusta
# Processing Record 43 of Set 5 | hatillo
# Processing Record 44 of Set 5 | salisbury
# Processing Record 45 of Set 5 | merrill
# Processing Record 46 of Set 5 | vysokogornyy
# Processing Record 47 of Set 5 | marzuq
# Processing Record 48 of Set 5 | dolores
# Processing Record 49 of Set 5 | poum
# Processing Record 50 of Set 5 | sehithwa
# Processing Record 1 of Set 6 | quatre cocos
# Processing Record 2 of Set 6 | afyonkarahisar
# Processing Record 3 of Set 6 | saskylakh
# Processing Record 4 of Set 6 | ponta do sol
# Processing Record 5 of Set 6 | havre-saint-pierre
# Processing Record 6 of Set 6 | maumere
# Processing Record 7 of Set 6 | shieli
# Processing Record 8 of Set 6 | yuli
# Processing Record 9 of Set 6 | airai
# Processing Record 10 of Set 6 | lazaro cardenas
# Processing Record 11 of Set 6 | severo-kurilsk
# Processing Record 12 of Set 6 | sao sebastiao
# Processing Record 13 of Set 6 | iqaluit
# Processing Record 14 of Set 6 | itaituba
# Processing Record 15 of Set 6 | kruisfontein
# Processing Record 16 of Set 6 | monte aprazivel
# Processing Record 17 of Set 6 | aranos
# Processing Record 18 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 6 | nanortalik
# Processing Record 20 of Set 6 | sao domingos
# Processing Record 21 of Set 6 | khash
# Processing Record 22 of Set 6 | tilichiki
# Processing Record 23 of Set 6 | hithadhoo
# Processing Record 24 of Set 6 | dingle
# Processing Record 25 of Set 6 | arys
# Processing Record 26 of Set 6 | morehead
# Processing Record 27 of Set 6 | coihaique
# Processing Record 28 of Set 6 | oranjemund
# Processing Record 29 of Set 6 | vestmannaeyjar
# Processing Record 30 of Set 6 | uvira
# Processing Record 31 of Set 6 | moa
# Processing Record 32 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 6 | mustasaari
# Processing Record 34 of Set 6 | anadyr
# Processing Record 35 of Set 6 | hambantota
# Processing Record 36 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 6 | kurchum
# Processing Record 38 of Set 6 | meulaboh
# Processing Record 39 of Set 6 | jumla
# Processing Record 40 of Set 6 | kalmunai
# Processing Record 41 of Set 6 | kijang
# Processing Record 42 of Set 6 | naze
# Processing Record 43 of Set 6 | konstantinovka
# Processing Record 44 of Set 6 | ribeira grande
# Processing Record 45 of Set 6 | wamba
# Processing Record 46 of Set 6 | sao joao da barra
# Processing Record 47 of Set 6 | yulara
# Processing Record 48 of Set 6 | mokhsogollokh
# Processing Record 49 of Set 6 | harrison
# Processing Record 50 of Set 6 | jaruco
# Processing Record 1 of Set 7 | muhos
# Processing Record 2 of Set 7 | lorengau
# Processing Record 3 of Set 7 | owando
# Processing Record 4 of Set 7 | gusinoye ozero
# Processing Record 5 of Set 7 | luderitz
# Processing Record 6 of Set 7 | haimen
# Processing Record 7 of Set 7 | carutapera
# Processing Record 8 of Set 7 | cayenne
# Processing Record 9 of Set 7 | mugango
# Processing Record 10 of Set 7 | dwarka
# Processing Record 11 of Set 7 | itoman
# Processing Record 12 of Set 7 | berbera
# Processing Record 13 of Set 7 | claremore
# Processing Record 14 of Set 7 | touros
# Processing Record 15 of Set 7 | prince albert
# Processing Record 16 of Set 7 | tombouctou
# Processing Record 17 of Set 7 | ileza
# Processing Record 18 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 7 | mangan
# Processing Record 20 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 7 | road town
# Processing Record 22 of Set 7 | torbay
# Processing Record 23 of Set 7 | columbus
# Processing Record 24 of Set 7 | smithers
# Processing Record 25 of Set 7 | tiksi
# Processing Record 26 of Set 7 | oxelosund
# Processing Record 27 of Set 7 | khorixas
# Processing Record 28 of Set 7 | rio grande
# Processing Record 29 of Set 7 | pilao arcado
# City not found. Skipping...
# Processing Record 30 of Set 7 | mangochi
# Processing Record 31 of Set 7 | lander
# Processing Record 32 of Set 7 | taubate
# Processing Record 33 of Set 7 | korla
# Processing Record 34 of Set 7 | berdigestyakh
# Processing Record 35 of Set 7 | luanda
# Processing Record 36 of Set 7 | palmer
# Processing Record 37 of Set 7 | kondoa
# Processing Record 38 of Set 7 | eydhafushi
# Processing Record 39 of Set 7 | college
# Processing Record 40 of Set 7 | strezhevoy
# Processing Record 41 of Set 7 | kamen-na-obi
# Processing Record 42 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 43 of Set 7 | buwenge
# Processing Record 44 of Set 7 | port hedland
# Processing Record 45 of Set 7 | aras
# Processing Record 46 of Set 7 | formosa do rio preto
# Processing Record 47 of Set 7 | cabadiangan
# Processing Record 48 of Set 7 | novikovo
# Processing Record 49 of Set 7 | astana
# Processing Record 50 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 8 | faya
# Processing Record 2 of Set 8 | ahuimanu
# Processing Record 3 of Set 8 | danville
# Processing Record 4 of Set 8 | tuatapere
# Processing Record 5 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 8 | klaksvik
# Processing Record 7 of Set 8 | walvis bay
# Processing Record 8 of Set 8 | bud
# Processing Record 9 of Set 8 | mildura
# Processing Record 10 of Set 8 | ketchikan
# Processing Record 11 of Set 8 | lujan
# Processing Record 12 of Set 8 | isiro
# Processing Record 13 of Set 8 | luba
# Processing Record 14 of Set 8 | ondangwa
# Processing Record 15 of Set 8 | tete
# Processing Record 16 of Set 8 | ugoofaaru
# Processing Record 17 of Set 8 | arzgir
# Processing Record 18 of Set 8 | kawalu
# Processing Record 19 of Set 8 | leh
# Processing Record 20 of Set 8 | maues
# Processing Record 21 of Set 8 | buala
# Processing Record 22 of Set 8 | buchanan
# Processing Record 23 of Set 8 | iquitos
# Processing Record 24 of Set 8 | valley station
# Processing Record 25 of Set 8 | mogochin
# City not found. Skipping...
# Processing Record 26 of Set 8 | derazhnya
# Processing Record 27 of Set 8 | kobryn
# Processing Record 28 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 8 | lahij
# Processing Record 30 of Set 8 | rosetta
# Processing Record 31 of Set 8 | vila franca do campo
# Processing Record 32 of Set 8 | namanga
# Processing Record 33 of Set 8 | vila velha
# Processing Record 34 of Set 8 | la serena
# Processing Record 35 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 8 | chiang mai
# Processing Record 37 of Set 8 | guiratinga
# Processing Record 38 of Set 8 | gandai
# Processing Record 39 of Set 8 | tiznit
# Processing Record 40 of Set 8 | haapiti
# Processing Record 41 of Set 8 | manteca
# Processing Record 42 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 43 of Set 8 | kuldur
# Processing Record 44 of Set 8 | viedma
# Processing Record 45 of Set 8 | santa isabel
# Processing Record 46 of Set 8 | geraldton
# Processing Record 47 of Set 8 | padang
# Processing Record 48 of Set 8 | yar-sale
# Processing Record 49 of Set 8 | neftegorsk
# Processing Record 50 of Set 8 | bambanglipuro
# Processing Record 1 of Set 9 | jinchengjiang
# City not found. Skipping...
# Processing Record 2 of Set 9 | vostok
# Processing Record 3 of Set 9 | aksarka
# Processing Record 4 of Set 9 | kautokeino
# Processing Record 5 of Set 9 | papara
# Processing Record 6 of Set 9 | magalia
# Processing Record 7 of Set 9 | sharjah
# Processing Record 8 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 9 of Set 9 | soyo
# Processing Record 10 of Set 9 | mount isa
# Processing Record 11 of Set 9 | gao
# Processing Record 12 of Set 9 | sumbe
# Processing Record 13 of Set 9 | vardo
# Processing Record 14 of Set 9 | waingapu
# Processing Record 15 of Set 9 | moerai
# Processing Record 16 of Set 9 | galesong
# Processing Record 17 of Set 9 | husavik
# Processing Record 18 of Set 9 | cascais
# Processing Record 19 of Set 9 | deder
# Processing Record 20 of Set 9 | bahia honda
# Processing Record 21 of Set 9 | litovko
# Processing Record 22 of Set 9 | orsha
# Processing Record 23 of Set 9 | coquimbo
# Processing Record 24 of Set 9 | rocky mountain house
# Processing Record 25 of Set 9 | balkhash
# Processing Record 26 of Set 9 | agrestina
# Processing Record 27 of Set 9 | yenagoa
# Processing Record 28 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 9 | riyadh
# Processing Record 30 of Set 9 | kuala terengganu
# Processing Record 31 of Set 9 | baoning
# Processing Record 32 of Set 9 | alcacer do sal
# Processing Record 33 of Set 9 | buraydah
# Processing Record 34 of Set 9 | caravelas
# Processing Record 35 of Set 9 | puerto leguizamo
# Processing Record 36 of Set 9 | pascagoula
# Processing Record 37 of Set 9 | chadiza
# Processing Record 38 of Set 9 | amilpas
# City not found. Skipping...
# Processing Record 39 of Set 9 | tapiramuta
# Processing Record 40 of Set 9 | borzna
# Processing Record 41 of Set 9 | salalah
# Processing Record 42 of Set 9 | praia
# Processing Record 43 of Set 9 | xichang
# Processing Record 44 of Set 9 | kidodi
# Processing Record 45 of Set 9 | diplo
# Processing Record 46 of Set 9 | san vicente
# Processing Record 47 of Set 9 | potsdam
# Processing Record 48 of Set 9 | varhaug
# Processing Record 49 of Set 9 | troy
# Processing Record 50 of Set 9 | emerald
# Processing Record 1 of Set 10 | beboto
# Processing Record 2 of Set 10 | maridi
# Processing Record 3 of Set 10 | grand gaube
# Processing Record 4 of Set 10 | bubaque
# Processing Record 5 of Set 10 | sioux lookout
# Processing Record 6 of Set 10 | srandakan
# Processing Record 7 of Set 10 | fare
# Processing Record 8 of Set 10 | chara
# Processing Record 9 of Set 10 | saint-francois
# Processing Record 10 of Set 10 | buguda
# Processing Record 11 of Set 10 | porto novo
# Processing Record 12 of Set 10 | kralendijk
# Processing Record 13 of Set 10 | sal rei
# Processing Record 14 of Set 10 | kaputa
# Processing Record 15 of Set 10 | tautira
# Processing Record 16 of Set 10 | baker city
# Processing Record 17 of Set 10 | horsham
# Processing Record 18 of Set 10 | palmira
# Processing Record 19 of Set 10 | bonavista
# Processing Record 20 of Set 10 | raga
# Processing Record 21 of Set 10 | ostrovnoy
# Processing Record 22 of Set 10 | acapulco
# Processing Record 23 of Set 10 | kulhudhuffushi
# Processing Record 24 of Set 10 | tezu
# Processing Record 25 of Set 10 | boende
# Processing Record 26 of Set 10 | wawa
# Processing Record 27 of Set 10 | batagay-alyta
# Processing Record 28 of Set 10 | wajid
# Processing Record 29 of Set 10 | jomalig
# City not found. Skipping...
# Processing Record 30 of Set 10 | fethiye
# Processing Record 31 of Set 10 | kalabo
# Processing Record 32 of Set 10 | esna
# Processing Record 33 of Set 10 | nago
# Processing Record 34 of Set 10 | ossora
# Processing Record 35 of Set 10 | trelew
# Processing Record 36 of Set 10 | morondava
# Processing Record 37 of Set 10 | ishigaki
# Processing Record 38 of Set 10 | revelstoke
# Processing Record 39 of Set 10 | los llanos de aridane
# Processing Record 40 of Set 10 | lasa
# Processing Record 41 of Set 10 | aketi
# Processing Record 42 of Set 10 | dalbandin
# Processing Record 43 of Set 10 | coahuayana
# Processing Record 44 of Set 10 | carlagan
# Processing Record 45 of Set 10 | bam
# Processing Record 46 of Set 10 | san cristobal
# Processing Record 47 of Set 10 | gweta
# Processing Record 48 of Set 10 | nanga eboko
# Processing Record 49 of Set 10 | butembo
# Processing Record 50 of Set 10 | cabedelo
# Processing Record 1 of Set 11 | jawhar
# Processing Record 2 of Set 11 | carberry
# Processing Record 3 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 4 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 11 | muros
# Processing Record 6 of Set 11 | iquique
# Processing Record 7 of Set 11 | kununurra
# Processing Record 8 of Set 11 | puerto del rosario
# Processing Record 9 of Set 11 | am timan
# Processing Record 10 of Set 11 | semnan
# Processing Record 11 of Set 11 | tecoanapa
# Processing Record 12 of Set 11 | charters towers
# Processing Record 13 of Set 11 | gornopravdinsk
# Processing Record 14 of Set 11 | saint john
# Processing Record 15 of Set 11 | belaya gora
# Processing Record 16 of Set 11 | barcelos
# Processing Record 17 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 18 of Set 11 | werdau
# Processing Record 19 of Set 11 | corinto
# Processing Record 20 of Set 11 | uk
# City not found. Skipping...
# Processing Record 21 of Set 11 | cairns
# Processing Record 22 of Set 11 | margate
# Processing Record 23 of Set 11 | rawson
# Processing Record 24 of Set 11 | nome
# Processing Record 25 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 11 | manhattan
# Processing Record 27 of Set 11 | bontang
# Processing Record 28 of Set 11 | port townsend
# Processing Record 29 of Set 11 | ilulissat
# Processing Record 30 of Set 11 | bo phloi
# Processing Record 31 of Set 11 | krasnoselkup
# Processing Record 32 of Set 11 | yelovo
# Processing Record 33 of Set 11 | mocuba
# Processing Record 34 of Set 11 | zhuhai
# Processing Record 35 of Set 11 | san quintin
# Processing Record 36 of Set 11 | gornozavodsk
# Processing Record 37 of Set 11 | waipawa
# Processing Record 38 of Set 11 | drexel heights
# Processing Record 39 of Set 11 | maine-soroa
# Processing Record 40 of Set 11 | sergiyevsk
# Processing Record 41 of Set 11 | ibra
# Processing Record 42 of Set 11 | gaoua
# Processing Record 43 of Set 11 | sinnamary
# Processing Record 44 of Set 11 | comodoro rivadavia
# Processing Record 45 of Set 11 | sept-iles
# Processing Record 46 of Set 11 | tiarei
# Processing Record 47 of Set 11 | asau
# Processing Record 48 of Set 11 | lakatoro
# Processing Record 49 of Set 11 | kavaratti
# Processing Record 50 of Set 11 | benxi
# Processing Record 1 of Set 12 | fortuna
# Processing Record 2 of Set 12 | port-gentil
# Processing Record 3 of Set 12 | kremenchuk
# Processing Record 4 of Set 12 | constantine
# Processing Record 5 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 12 | prozor
# Processing Record 7 of Set 12 | aksu
# Processing Record 8 of Set 12 | portland
# Processing Record 9 of Set 12 | dali
# Processing Record 10 of Set 12 | conceicao do araguaia
# Processing Record 11 of Set 12 | hanstholm
# Processing Record 12 of Set 12 | chake chake
# Processing Record 13 of Set 12 | samarai
# Processing Record 14 of Set 12 | nushki
# Processing Record 15 of Set 12 | ulaangom
# Processing Record 16 of Set 12 | terrace
# Processing Record 17 of Set 12 | christchurch
# Processing Record 18 of Set 12 | harper
# Processing Record 19 of Set 12 | morro bay
# Processing Record 20 of Set 12 | zelenets
# Processing Record 21 of Set 12 | quang ngai
# Processing Record 22 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 23 of Set 12 | igarka
# Processing Record 24 of Set 12 | sidney
# Processing Record 25 of Set 12 | beringovskiy
# Processing Record 26 of Set 12 | vallenar
# Processing Record 27 of Set 12 | atascadero
# Processing Record 28 of Set 12 | rehoboth
# Processing Record 29 of Set 12 | kachug
# Processing Record 30 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 31 of Set 12 | udachnyy
# Processing Record 32 of Set 12 | kargopol
# Processing Record 33 of Set 12 | brzesko
# Processing Record 34 of Set 12 | inta
# Processing Record 35 of Set 12 | bindi
# Processing Record 36 of Set 12 | zyryanka
# Processing Record 37 of Set 12 | bahia blanca
# Processing Record 38 of Set 12 | ambon
# Processing Record 39 of Set 12 | yangambi
# Processing Record 40 of Set 12 | vestmanna
# Processing Record 41 of Set 12 | alfredo baquerizo moreno
# Processing Record 42 of Set 12 | kathu
# Processing Record 43 of Set 12 | panaba
# Processing Record 44 of Set 12 | laguna
# Processing Record 45 of Set 12 | baherden
# Processing Record 46 of Set 12 | andenes
# Processing Record 47 of Set 12 | veraval
# Processing Record 48 of Set 12 | port blair
# Processing Record 49 of Set 12 | sarai naurang
# Processing Record 50 of Set 12 | pacific grove
# Processing Record 1 of Set 13 | sagua la grande
# Processing Record 2 of Set 13 | richards bay
# Processing Record 3 of Set 13 | monte alto
# Processing Record 4 of Set 13 | iisalmi
# Processing Record 5 of Set 13 | beloha
# Processing Record 6 of Set 13 | inhambane
# Processing Record 7 of Set 13 | areia branca
# Processing Record 8 of Set 13 | lodja
# Processing Record 9 of Set 13 | sovetskaya gavan
# Processing Record 10 of Set 13 | sistranda
# Processing Record 11 of Set 13 | muisne
# Processing Record 12 of Set 13 | benguela
# Processing Record 13 of Set 13 | novoilinsk
# Processing Record 14 of Set 13 | homer
# Processing Record 15 of Set 13 | ayna
# Processing Record 16 of Set 13 | shelburne
# Processing Record 17 of Set 13 | hammerfest
# Processing Record 18 of Set 13 | verkhnevilyuysk
# Processing Record 19 of Set 13 | makakilo city
# Processing Record 20 of Set 13 | magdagachi
# Processing Record 21 of Set 13 | changli
# Processing Record 22 of Set 13 | seddon
# Processing Record 23 of Set 13 | yining
# Processing Record 24 of Set 13 | sivaki
# Processing Record 25 of Set 13 | samatau
# City not found. Skipping...
# Processing Record 26 of Set 13 | rossosh
# Processing Record 27 of Set 13 | jacareacanga
# Processing Record 28 of Set 13 | buluang
# Processing Record 29 of Set 13 | sainte-anne-des-monts
# Processing Record 30 of Set 13 | malampaka
# Processing Record 31 of Set 13 | jibuti
# Processing Record 32 of Set 13 | kalevala
# Processing Record 33 of Set 13 | andros town
# Processing Record 34 of Set 13 | portsmouth
# Processing Record 35 of Set 13 | mlonggo
# Processing Record 36 of Set 13 | alirajpur
# Processing Record 37 of Set 13 | aktash
# Processing Record 38 of Set 13 | wanning
# Processing Record 39 of Set 13 | madingou
# Processing Record 40 of Set 13 | jhang
# Processing Record 41 of Set 13 | garowe
# Processing Record 42 of Set 13 | kjollefjord
# Processing Record 43 of Set 13 | songjianghe
# Processing Record 44 of Set 13 | sechura
# Processing Record 45 of Set 13 | tateyama
# Processing Record 46 of Set 13 | dondo
# Processing Record 47 of Set 13 | delta del tigre
# Processing Record 48 of Set 13 | liverpool
# Processing Record 49 of Set 13 | pisco
# Processing Record 50 of Set 13 | hervey bay
# Processing Record 1 of Set 14 | salamiyah
# Processing Record 2 of Set 14 | vargashi
# Processing Record 3 of Set 14 | bodinayakkanur
# Processing Record 4 of Set 14 | avera
# Processing Record 5 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 6 of Set 14 | sarospatak
# Processing Record 7 of Set 14 | auki
# Processing Record 8 of Set 14 | mount kisco
# Processing Record 9 of Set 14 | namibe
# Processing Record 10 of Set 14 | ovre ardal
# Processing Record 11 of Set 14 | predivinsk
# Processing Record 12 of Set 14 | ploemeur
# Processing Record 13 of Set 14 | darhan
# Processing Record 14 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 15 of Set 14 | balykshi
# Processing Record 16 of Set 14 | yilan
# Processing Record 17 of Set 14 | blagodatnoye
# Processing Record 18 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 19 of Set 14 | kudahuvadhoo
# Processing Record 20 of Set 14 | sao felix do xingu
# Processing Record 21 of Set 14 | sao gotardo
# Processing Record 22 of Set 14 | sarangani
# Processing Record 23 of Set 14 | naberera
# Processing Record 24 of Set 14 | amahai
# Processing Record 25 of Set 14 | kayes
# Processing Record 26 of Set 14 | mamallapuram
# Processing Record 27 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 28 of Set 14 | maarianhamina
# Processing Record 29 of Set 14 | kedougou
# Processing Record 30 of Set 14 | duz
# City not found. Skipping...
# Processing Record 31 of Set 14 | goderich
# Processing Record 32 of Set 14 | okhotsk
# Processing Record 33 of Set 14 | huilong
# Processing Record 34 of Set 14 | marawi
# Processing Record 35 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 36 of Set 14 | baruun-urt
# Processing Record 37 of Set 14 | westport
# Processing Record 38 of Set 14 | itigi
# Processing Record 39 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 14 | vikhorevka
# Processing Record 41 of Set 14 | novorudnyy
# Processing Record 42 of Set 14 | boralday
# Processing Record 43 of Set 14 | nemuro
# Processing Record 44 of Set 14 | magdalena
# Processing Record 45 of Set 14 | mayahi
# Processing Record 46 of Set 14 | coihueco
# Processing Record 47 of Set 14 | manzanillo
# Processing Record 48 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 14 | huarmey
# Processing Record 50 of Set 14 | primorsk
# Processing Record 1 of Set 15 | lavrentiya
# Processing Record 2 of Set 15 | hadejia
# Processing Record 3 of Set 15 | hay river
# Processing Record 4 of Set 15 | trinidad
# Processing Record 5 of Set 15 | swellendam
# Processing Record 6 of Set 15 | yeppoon
# Processing Record 7 of Set 15 | bhawanipatna
# Processing Record 8 of Set 15 | virginia beach
# Processing Record 9 of Set 15 | tretten
# Processing Record 10 of Set 15 | sao jose da coroa grande
# Processing Record 11 of Set 15 | gijon
# Processing Record 12 of Set 15 | yaan
# Processing Record 13 of Set 15 | kenai
# City not found. Skipping...
# Processing Record 14 of Set 15 | dhidhdhoo
# Processing Record 15 of Set 15 | den helder
# Processing Record 16 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 17 of Set 15 | peniche
# Processing Record 18 of Set 15 | santa cruz
# Processing Record 19 of Set 15 | chapais
# Processing Record 20 of Set 15 | chapleau
# Processing Record 21 of Set 15 | bezhanitsy
# Processing Record 22 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 15 | birjand
# Processing Record 24 of Set 15 | mahabad
# Processing Record 25 of Set 15 | olinda
# Processing Record 26 of Set 15 | glen allen
# Processing Record 27 of Set 15 | abha
# Processing Record 28 of Set 15 | ambilobe
# Processing Record 29 of Set 15 | ayorou
# Processing Record 30 of Set 15 | labuan
# Processing Record 31 of Set 15 | vrangel
# Processing Record 32 of Set 15 | tynda
# Processing Record 33 of Set 15 | bellavista
# Processing Record 34 of Set 15 | haines junction
# Processing Record 35 of Set 15 | gavrilov posad
# Processing Record 36 of Set 15 | trofors
# Processing Record 37 of Set 15 | fontanafredda
# Processing Record 38 of Set 15 | aykhal
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 681

# %%
# Save the new DataFrame as a CSV File
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df.to_csv(path_or_buf='WeatherPy_challenge.csv', index_label='City_ID')
